# %%
import requests
from bs4 import BeautifulSoup
import csv
# Make a request
page = requests.get(
    "https://realpython.github.io/fake-jobs/")
soup = BeautifulSoup(page.content, 'html.parser')

# Create top_items as empty list
all_jobs = []

# Extract and store in top_items according to instructions on the left
jobs = soup.find_all("div", {"class": "card"})
for job in jobs:
    job_title = job.find('h2').text.strip()
    company = job.find('h3').text.strip()
    location = job.find('p').text.strip()
    date = job.find('time').text.strip()
    

    all_jobs.append({
        "job_title": job_title,
        "company":   company,
		    "location": location,
        "date": date,     
    })

for i in all_jobs:
    print (i)

keys = all_jobs[0].keys()

with open('jobs.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_jobs)
# Out:
# {'job_title': 'Senior Python Developer', 'company': 'Payne, Roberts and Davis', 'location': 'Stewartbury, AA', 'date': '2021-04-08'}
# {'job_title': 'Energy engineer', 'company': 'Vasquez-Davidson', 'location': 'Christopherville, AA', 'date': '2021-04-08'}
# {'job_title': 'Legal executive', 'company': 'Jackson, Chambers and Levy', 'location': 'Port Ericaburgh, AA', 'date': '2021-04-08'}
# {'job_title': 'Fitness centre manager', 'company': 'Savage-Bradley', 'location': 'East Seanview, AP', 'date': '2021-04-08'}
# {'job_title': 'Product manager', 'company': 'Ramirez Inc', 'location': 'North Jamieview, AP', 'date': '2021-04-08'}
# {'job_title': 'Medical technical officer', 'company': 'Rogers-Yates', 'location': 'Davidville, AP', 'date': '2021-04-08'}
# {'job_title': 'Physiological scientist', 'company': 'Kramer-Klein', 'location': 'South Christopher, AE', 'date': '2021-04-08'}
# {'job_title': 'Textile designer', 'company': 'Meyers-Johnson', 'location': 'Port Jonathan, AE', 'date': '2021-04-08'}
# {'job_title': 'Television floor manager', 'company': 'Hughes-Williams', 'location': 'Osbornetown, AE', 'date': '2021-04-08'}
# {'job_title': 'Waste management officer', 'company': 'Jones, Williams and Villa', 'location': 'Scotttown, AP', 'date': '2021-04-08'}
# {'job_title': 'Software Engineer (Python)', 'company': 'Garcia PLC', 'location': 'Ericberg, AE', 'date': '2021-04-08'}
# {'job_title': 'Interpreter', 'company': 'Gregory and Sons', 'location': 'Ramireztown, AE', 'date': '2021-04-08'}
# {'job_title': 'Architect', 'company': 'Clark, Garcia and Sosa', 'location': 'Figueroaview, AA', 'date': '2021-04-08'}
# {'job_title': 'Meteorologist', 'company': 'Bush PLC', 'location': 'Kelseystad, AA', 'date': '2021-04-08'}
# {'job_title': 'Audiological scientist', 'company': 'Salazar-Meyers', 'location': 'Williamsburgh, AE', 'date': '2021-04-08'}
# {'job_title': 'English as a second language teacher', 'company': 'Parker, Murphy and Brooks', 'location': 'Mitchellburgh, AE', 'date': '2021-04-08'}
# {'job_title': 'Surgeon', 'company': 'Cruz-Brown', 'location': 'West Jessicabury, AA', 'date': '2021-04-08'}
# {'job_title': 'Equities trader', 'company': 'Macdonald-Ferguson', 'location': 'Maloneshire, AE', 'date': '2021-04-08'}
# {'job_title': 'Newspaper journalist', 'company': 'Williams, Peterson and Rojas', 'location': 'Johnsonton, AA', 'date': '2021-04-08'}
# {'job_title': 'Materials engineer', 'company': 'Smith and Sons', 'location': 'South Davidtown, AP', 'date': '2021-04-08'}
# {'job_title': 'Python Programmer (Entry-Level)', 'company': 'Moss, Duncan and Allen', 'location': 'Port Sara, AE', 'date': '2021-04-08'}
# {'job_title': 'Product/process development scientist', 'company': 'Gomez-Carroll', 'location': 'Marktown, AA', 'date': '2021-04-08'}
# {'job_title': 'Scientist, research (maths)', 'company': 'Manning, Welch and Herring', 'location': 'Laurenland, AE', 'date': '2021-04-08'}
# {'job_title': 'Ecologist', 'company': 'Lee, Gutierrez and Brown', 'location': 'Lauraton, AP', 'date': '2021-04-08'}
# {'job_title': 'Materials engineer', 'company': 'Davis, Serrano and Cook', 'location': 'South Tammyberg, AP', 'date': '2021-04-08'}
# {'job_title': 'Historic buildings inspector/conservation officer', 'company': 'Smith LLC', 'location': 'North Brandonville, AP', 'date': '2021-04-08'}
# {'job_title': 'Data scientist', 'company': 'Thomas Group', 'location': 'Port Robertfurt, AA', 'date': '2021-04-08'}
# {'job_title': 'Psychiatrist', 'company': 'Silva-King', 'location': 'Burnettbury, AE', 'date': '2021-04-08'}
# {'job_title': 'Structural engineer', 'company': 'Pierce-Long', 'location': 'Herbertside, AA', 'date': '2021-04-08'}
# {'job_title': 'Immigration officer', 'company': 'Walker-Simpson', 'location': 'Christopherport, AP', 'date': '2021-04-08'}
# {'job_title': 'Python Programmer (Entry-Level)', 'company': 'Cooper and Sons', 'location': 'West Victor, AE', 'date': '2021-04-08'}
# {'job_title': 'Neurosurgeon', 'company': 'Donovan, Gonzalez and Figueroa', 'location': 'Port Aaron, AP', 'date': '2021-04-08'}
# {'job_title': 'Broadcast engineer', 'company': 'Morgan, Butler and Bennett', 'location': 'Loribury, AA', 'date': '2021-04-08'}
# {'job_title': 'Make', 'company': 'Snyder-Lee', 'location': 'Angelastad, AP', 'date': '2021-04-08'}
# {'job_title': 'Nurse, adult', 'company': 'Harris PLC', 'location': 'Larrytown, AE', 'date': '2021-04-08'}
# {'job_title': 'Air broker', 'company': 'Washington PLC', 'location': 'West Colin, AP', 'date': '2021-04-08'}
# {'job_title': 'Editor, film/video', 'company': 'Brown, Price and Campbell', 'location': 'West Stephanie, AP', 'date': '2021-04-08'}
# {'job_title': 'Production assistant, radio', 'company': 'Mcgee PLC', 'location': 'Laurentown, AP', 'date': '2021-04-08'}
# {'job_title': 'Engineer, communications', 'company': 'Dixon Inc', 'location': 'Wrightberg, AP', 'date': '2021-04-08'}
# {'job_title': 'Sales executive', 'company': 'Thompson, Sheppard and Ward', 'location': 'Alberttown, AE', 'date': '2021-04-08'}
# {'job_title': 'Software Developer (Python)', 'company': 'Adams-Brewer', 'location': 'Brockburgh, AE', 'date': '2021-04-08'}
# {'job_title': 'Futures trader', 'company': 'Schneider-Brady', 'location': 'North Jason, AE', 'date': '2021-04-08'}
# {'job_title': 'Tour manager', 'company': 'Gonzales-Frank', 'location': 'Arnoldhaven, AE', 'date': '2021-04-08'}
# {'job_title': 'Cytogeneticist', 'company': 'Smith-Wong', 'location': 'Lake Destiny, AP', 'date': '2021-04-08'}
# {'job_title': 'Designer, multimedia', 'company': 'Pierce-Herrera', 'location': 'South Timothyburgh, AP', 'date': '2021-04-08'}
# {'job_title': 'Trade union research officer', 'company': 'Aguilar, Rivera and Quinn', 'location': 'New Jimmyton, AE', 'date': '2021-04-08'}
# {'job_title': 'Chemist, analytical', 'company': 'Lowe, Barnes and Thomas', 'location': 'New Lucasbury, AP', 'date': '2021-04-08'}
# {'job_title': 'Programmer, multimedia', 'company': 'Lewis, Gonzalez and Vasquez', 'location': 'Port Cory, AE', 'date': '2021-04-08'}
# {'job_title': 'Engineer, broadcasting (operations)', 'company': 'Taylor PLC', 'location': 'Gileston, AA', 'date': '2021-04-08'}
# {'job_title': 'Teacher, primary school', 'company': 'Oliver, Jones and Ramirez', 'location': 'Cindyshire, AA', 'date': '2021-04-08'}
# {'job_title': 'Python Developer', 'company': 'Rivera and Sons', 'location': 'East Michaelfort, AA', 'date': '2021-04-08'}
# {'job_title': 'Manufacturing systems engineer', 'company': 'Garcia PLC', 'location': 'Joybury, AE', 'date': '2021-04-08'}
# {'job_title': 'Producer, television/film/video', 'company': 'Johnson, Wells and Kramer', 'location': 'Emmatown, AE', 'date': '2021-04-08'}
# {'job_title': 'Scientist, forensic', 'company': 'Gonzalez LLC', 'location': 'Colehaven, AP', 'date': '2021-04-08'}
# {'job_title': 'Bonds trader', 'company': 'Morgan, White and Macdonald', 'location': 'Port Coryton, AE', 'date': '2021-04-08'}
# {'job_title': 'Editorial assistant', 'company': 'Robinson-Fitzpatrick', 'location': 'Amyborough, AA', 'date': '2021-04-08'}
# {'job_title': 'Photographer', 'company': 'Waters, Wilson and Hoover', 'location': 'Reynoldsville, AA', 'date': '2021-04-08'}
# {'job_title': 'Retail banker', 'company': 'Hill LLC', 'location': 'Port Billy, AP', 'date': '2021-04-08'}
# {'job_title': 'Jewellery designer', 'company': 'Li-Gregory', 'location': 'Adamburgh, AA', 'date': '2021-04-08'}
# {'job_title': 'Ophthalmologist', 'company': 'Fisher, Ryan and Coleman', 'location': 'Wilsonmouth, AA', 'date': '2021-04-08'}
# {'job_title': 'Back-End Web Developer (Python, Django)', 'company': 'Stewart-Alexander', 'location': 'South Kimberly, AA', 'date': '2021-04-08'}
# {'job_title': 'Licensed conveyancer', 'company': 'Abbott and Sons', 'location': 'Benjaminland, AP', 'date': '2021-04-08'}
# {'job_title': 'Futures trader', 'company': 'Bryant, Santana and Davenport', 'location': 'Zacharyport, AA', 'date': '2021-04-08'}
# {'job_title': 'Counselling psychologist', 'company': 'Smith PLC', 'location': 'Port Devonville, AE', 'date': '2021-04-08'}
# {'job_title': 'Insurance underwriter', 'company': 'Patterson-Singh', 'location': 'East Thomas, AE', 'date': '2021-04-08'}
# {'job_title': 'Engineer, automotive', 'company': 'Martinez-Berry', 'location': 'New Jeffrey, AP', 'date': '2021-04-08'}
# {'job_title': 'Producer, radio', 'company': 'May, Taylor and Fisher', 'location': 'Davidside, AA', 'date': '2021-04-08'}
# {'job_title': 'Dispensing optician', 'company': 'Bailey, Owen and Thompson', 'location': 'Jamesville, AA', 'date': '2021-04-08'}
# {'job_title': 'Designer, fashion/clothing', 'company': 'Vasquez Ltd', 'location': 'New Kelly, AP', 'date': '2021-04-08'}
# {'job_title': 'Chartered loss adjuster', 'company': 'Leblanc LLC', 'location': 'Lake Antonio, AA', 'date': '2021-04-08'}
# {'job_title': 'Back-End Web Developer (Python, Django)', 'company': 'Jackson, Ali and Mckee', 'location': 'New Elizabethside, AA', 'date': '2021-04-08'}
# {'job_title': 'Forest/woodland manager', 'company': 'Blankenship, Knight and Powell', 'location': 'Millsbury, AE', 'date': '2021-04-08'}
# {'job_title': 'Clinical cytogeneticist', 'company': 'Patton, Haynes and Jones', 'location': 'Lloydton, AP', 'date': '2021-04-08'}
# {'job_title': 'Print production planner', 'company': 'Wood Inc', 'location': 'Port Jeremy, AA', 'date': '2021-04-08'}
# {'job_title': 'Systems developer', 'company': 'Collins Group', 'location': 'New Elizabethtown, AA', 'date': '2021-04-08'}
# {'job_title': 'Graphic designer', 'company': 'Flores-Nelson', 'location': 'Charlesstad, AE', 'date': '2021-04-08'}
# {'job_title': 'Writer', 'company': 'Mitchell, Jones and Olson', 'location': 'Josephbury, AE', 'date': '2021-04-08'}
# {'job_title': 'Field seismologist', 'company': 'Howard Group', 'location': 'Seanfurt, AA', 'date': '2021-04-08'}
# {'job_title': 'Chief Strategy Officer', 'company': 'Kramer-Edwards', 'location': 'Williambury, AA', 'date': '2021-04-08'}
# {'job_title': 'Air cabin crew', 'company': 'Berry-Houston', 'location': 'South Jorgeside, AP', 'date': '2021-04-08'}
# {'job_title': 'Python Programmer (Entry-Level)', 'company': 'Mathews Inc', 'location': 'Robertborough, AP', 'date': '2021-04-08'}
# {'job_title': 'Warden/ranger', 'company': 'Riley-Johnson', 'location': 'South Saratown, AP', 'date': '2021-04-08'}
# {'job_title': 'Sports therapist', 'company': 'Spencer and Sons', 'location': 'Hullview, AA', 'date': '2021-04-08'}
# {'job_title': 'Arts development officer', 'company': 'Camacho-Sanchez', 'location': 'Philipland, AP', 'date': '2021-04-08'}
# {'job_title': 'Printmaker', 'company': 'Oliver and Sons', 'location': 'North Patty, AE', 'date': '2021-04-08'}
# {'job_title': 'Health and safety adviser', 'company': 'Eaton PLC', 'location': 'North Stephen, AE', 'date': '2021-04-08'}
# {'job_title': 'Manufacturing systems engineer', 'company': 'Stanley-Frederick', 'location': 'Stevensland, AP', 'date': '2021-04-08'}
# {'job_title': 'Programmer, applications', 'company': 'Bradley LLC', 'location': 'Reyesstad, AE', 'date': '2021-04-08'}
# {'job_title': 'Medical physicist', 'company': 'Parker, Goodwin and Zavala', 'location': 'Bellberg, AP', 'date': '2021-04-08'}
# {'job_title': 'Media planner', 'company': 'Kim-Miles', 'location': 'North Johnland, AE', 'date': '2021-04-08'}
# {'job_title': 'Software Developer (Python)', 'company': 'Moreno-Rodriguez', 'location': 'Martinezburgh, AE', 'date': '2021-04-08'}
# {'job_title': 'Surveyor, land/geomatics', 'company': 'Brown-Ortiz', 'location': 'Joshuatown, AE', 'date': '2021-04-08'}
# {'job_title': 'Legal executive', 'company': 'Hartman PLC', 'location': 'West Ericstad, AA', 'date': '2021-04-08'}
# {'job_title': 'Librarian, academic', 'company': 'Brooks Inc', 'location': 'Tuckertown, AE', 'date': '2021-04-08'}
# {'job_title': 'Barrister', 'company': 'Washington-Castillo', 'location': 'Perezton, AE', 'date': '2021-04-08'}
# {'job_title': 'Museum/gallery exhibitions officer', 'company': 'Nguyen, Yoder and Petty', 'location': 'Lake Abigail, AE', 'date': '2021-04-08'}
# {'job_title': 'Radiographer, diagnostic', 'company': 'Holder LLC', 'location': 'Jacobshire, AP', 'date': '2021-04-08'}
# {'job_title': 'Database administrator', 'company': 'Yates-Ferguson', 'location': 'Port Susan, AE', 'date': '2021-04-08'}
# {'job_title': 'Furniture designer', 'company': 'Ortega-Lawrence', 'location': 'North Tiffany, AA', 'date': '2021-04-08'}
# {'job_title': 'Ship broker', 'company': 'Fuentes, Walls and Castro', 'location': 'Michelleville, AP', 'date': '2021-04-08'}
